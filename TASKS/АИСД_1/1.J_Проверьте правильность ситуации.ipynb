# %%
l = [list(map(int, input().split())) for i in range(3)]

# import random
# l= [[random.randint(0,2),random.randint(0,2),random.randint(0,2)] for i in range(3)]

x = 0
marker = 0

#!ставим x+=1 (чек последний блок)



#l = [list(map(int, input().split())) for i in range(3)]
x = 0
marker = 0
k, n = 0, 0

for i in l:
    for j in i:
        if j==1: k+=1
        elif j==2: n+=1

if l[0][0] == l[0][1] == l[0][2] != 0:
    x += l[0][0]
    marker += 1
if l[1][0] == l[1][1] == l[1][2] != 0:
    x += l[1][0]
    marker += 1
if l[2][0] == l[2][1] == l[2][2] != 0:
    x += l[2][0]
    marker += 1
if l[0][0] == l[1][0] == l[2][0] != 0:
    x += l[0][0]
    marker += 1
if l[0][1] == l[1][1] == l[2][1] != 0:
    x += l[0][1]
    marker += 1
if l[0][2] == l[1][2] == l[2][2] != 0:
    x += l[0][2]
    marker += 1
if l[0][0] == l[1][1] == l[2][2] != 0:
    x += l[0][0]
    marker += 1
if l[0][2] == l[1][1] == l[2][0] != 0:
    x += l[0][2]
    marker += 1
  
if marker == 0: 
    if k - n in [0,1]:
        print('YES')
    else:
        print('NO')
        
elif marker == 1:
    if x == 1:
        if k - n == 1:
            print('YES')
        else:
            print('NO')
            
    else:
        if k == n:
            print('YES')
        else:
            print('NO')
            
#!!!!!!!!из проверки снизу переделываем эту строчку, !!т к ситуация с маркер == 2 возможна при крестиках если k-n == 1
else:
    if x == 2 and k - n == 1:
        print('YES')
    else:
        print('NO')
#(БЫЛО: else: print('NO'))

# if (k-n not in [0,1]) or (marker > 1) or (x == 1 and (k-n!=1)) or (x == 2 and k!=n): print('NO')
# else: print('YES')



#!!!!!!!маркер 3 бывает двух видов: когда обе строки крестики или одна нолики другая крестики или обе нолики, последняя
# не подходит сразу, первая подходит при k-n == 1, вторая не подходит сразу
# Out:
# 1 1 1 1 1 1 1 1 1

# %%
#проверка для дурного 19-го теста, непр тест : 2 2 1   2 1 2   1 1 1



# import random
# for i in range(1000):
#     ans1, ans2 = 0, 0
#     l= [[random.randint(0,2),random.randint(0,2),random.randint(0,2)] for i in range(3)]
#
#     x = None
#     marker = 0
#
#     # l = [list(map(int, input().split())) for i in range(3)]
#     x = None
#     marker = 0
#     k, n = 0, 0
#
#     for i in l:
#         for j in i:
#             if j == 1:
#                 k += 1
#             elif j == 2:
#                 n += 1
#
#     if l[0][0] == l[0][1] == l[0][2] != 0:
#         x = l[0][0]
#         marker += 1
#     if l[1][0] == l[1][1] == l[1][2] != 0:
#         x = l[1][0]
#         marker += 1
#     if l[2][0] == l[2][1] == l[2][2] != 0:
#         x = l[2][0]
#         marker += 1
#     if l[0][0] == l[1][0] == l[2][0] != 0:
#         x = l[0][0]
#         marker += 1
#     if l[0][1] == l[1][1] == l[2][1] != 0:
#         x = l[0][1]
#         marker += 1
#     if l[0][2] == l[1][2] == l[2][2] != 0:
#         x = l[0][2]
#         marker += 1
#     if l[0][0] == l[1][1] == l[2][2] != 0:
#         x = l[0][0]
#         marker += 1
#     if l[0][2] == l[1][1] == l[2][0] != 0:
#         x = l[0][2]
#         marker += 1
#
#     if marker == 0:
#         if k - n in [0, 1]:
#             ans1 = 'YES'
#         else:
#             ans1 = 'NO'
#     elif marker == 1:
#         if x == 1:
#             if k - n == 1:
#                 ans1 = 'YES'
#             else:
#                 ans1 = 'NO'
#         else:
#             if k == n:
#                 ans1 = 'YES'
#             else:
#                 ans1 = 'NO'
#     else:
#         ans1 = 'NO'
#
#
#
#
#
#
#
#     k = 0
#     one = 0
#     two = 0
#     for i in l:
#         for j in i:
#             if j == 1:
#                 one += 1
#             elif j == 2:
#                 two += 1
#     b1 = b2 = b3 = b4 = b5 = b6 = b7 = b8 = 0
#     for_two = 0
#     if l[0][0] == l[0][1] == l[0][2] != 0:  # 1 строка
#         k += 1
#         b1 = 1
#         if l[0][2] == 2:
#             for_two += 1
#     if l[1][0] == l[1][1] == l[1][2] != 0:  # 2 строка
#         k += 1
#         b7 = 1
#         if l[1][2] == 2:
#             for_two += 1
#     if l[2][0] == l[2][1] == l[2][2] != 0:  # 3 строка
#         k += 1
#         b8 = 1
#         if l[2][2] == 2:
#             for_two += 1
#     if l[0][0] == l[1][0] == l[2][0] != 0:  # 1 столбец
#         k += 1
#         b2 = 1
#         if l[2][0] == 2:
#             for_two += 1
#     if l[0][1] == l[1][1] == l[2][1] != 0:  # 2 столбец
#         k += 1
#         b4 = 1
#         if l[2][1] == 2:
#             for_two += 1
#     if l[0][2] == l[1][2] == l[2][2] != 0:  # 3 столбец
#         k += 1
#         b5 = 1
#         if l[2][2] == 2:
#             for_two += 1
#     if l[0][0] == l[1][1] == l[2][2] != 0:  # главная диагональ
#         k += 1
#         b3 = 1
#         if l[2][2] == 2:
#             for_two += 1
#     if l[2][0] == l[1][1] == l[0][2] != 0:  # побочная диагональ
#         k += 1
#         b6 = 1
#         if l[0][2] == 2:
#             for_two += 1
#     if k == 0:
#         if 0 <= one - two < 2:
#             ans2 = "YES"
#         else:
#             ans2 = "NO"
#     elif k - for_two > 0:
#         if for_two > 0:
#             ans2 = "NO"
#         elif 0 < one - two < 2:
#             ans2 = "YES"
#         else:
#             ans2 = "NO"
#     else:
#         if two == one:
#             ans2 = "YES"
#         else:
#             ans2 = "NO"
#
#
#     if ans1 != ans2:
#         print(l)
#         print(ans1, ans2)

# %%
# короче вот самые коварные тесты:
# 221 212 111
# после учета теста сверху:
# 222 111 100
# и
# 111 222 100
